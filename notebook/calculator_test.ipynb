# %%
print("Advanced Calculator")
print("1 Add | 2 Subtract | 3 Multiply | 4 Divide")
print("5 Power | 6 Square Root | 7 Factorial")
print("8 Trigonometry | 9 Log | 10 Expression | 11 History")

choice = input("Enter choice: 2 ")
print("You chose:", choice)

if choice == "1":
    a, b = map(float, input("Enter two numbers: ").split())
    result = add(a, b)

elif choice == "2":
    a, b = map(float, input("Enter two numbers: ").split())
    result = subtract(a, b)

elif choice == "3":
    a, b = map(float, input("Enter two numbers: ").split())
    result = multiply(a, b)

elif choice == "4":
    a, b = map(float, input("Enter two numbers: ").split())
    result = divide(a, b)

elif choice == "5":
    a, b = map(float, input("Enter base and power: ").split())
    result = power(a, b)

elif choice == "6":
    a = float(input("Enter number: "))
    result = square_root(a)

elif choice == "7":
    a = int(input("Enter number: "))
    result = factorial(a)

elif choice == "8":
    func = input("sin / cos / tan: ")
    value = float(input("Enter angle in degrees: "))
    result = trigonometry(func, value)
# Out:
# Advanced Calculator
# 1 Add | 2 Subtract | 3 Multiply | 4 Divide
# 5 Power | 6 Square Root | 7 Factorial
# 8 Trigonometry | 9 Log | 10 Expression | 11 History

# %%
import math

history = []

def add(a, b): 
    return a + b

def subtract(a, b): 
    return a - b

def multiply(a, b): 
    return a * b

def divide(a, b):
    if b == 0:
        return "Error: Division by zero"
    return a / b

def power(a, b): 
    return a ** b

def square_root(a):
    if a < 0:
        return "Error: Negative number"
    return math.sqrt(a)

def factorial(a):
    if a < 0:
        return "Error: Negative number"
    return math.factorial(a)

def trigonometry(func, value):
    value = math.radians(value)
    if func == "sin": 
        return math.sin(value)
    if func == "cos": 
        return math.cos(value)
    if func == "tan": 
        return math.tan(value)

def logarithm(a):
    if a <= 0:
        return "Error: Log undefined"
    return math.log10(a)

def evaluate_expression(expr):
    try:
        return eval(expr)
    except:
        return "Invalid expression"

def show_history():
    if not history:
        print("No history available.")
    else:
        for item in history:
            print(item)
